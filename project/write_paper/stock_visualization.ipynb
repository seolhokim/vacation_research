# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
stock = pd.read_csv(r'C:\Users\TACTICS_1\Desktop\dji.csv')
# %matplotlib inline

# %%
stock.dropna(inplace=True)

# %%
# 정규 표준화 척도조정
from sklearn.preprocessing import StandardScaler
stdscaler = StandardScaler()
stock_pre = pd.DataFrame(stdscaler.fit_transform(stock))

# %%
stock_pre = stock_pre[0:100]

# %%
three = stock_pre.copy()

# %%
three=three.rolling(3).mean()

# %%
three[1]=three[1].shift(3)
three[2]=three[2].shift(3)
three[3]=three[3].shift(3)
three[4]=three[4].shift(3)
three[5]=three[5].shift(3)

# %%
three
# Out:
#           0         1         2         3         4         5         6   \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  -1.095785       NaN       NaN       NaN       NaN       NaN -0.646123
# 3  -1.095578       NaN       NaN       NaN       NaN       NaN -1.130389
# 4  -1.095372       NaN       NaN       NaN       NaN       NaN -1.560848
# 5  -1.095028 -0.651164 -1.152396 -1.035270 -0.459336 -0.164084 -1.722270
# 6  -1.094685 -1.139644 -0.634055 -0.762873 -1.240729 -0.598833 -1.560848
# 7  -1.094341 -1.560966 -0.636231 -0.533961 -0.905302 -1.512130 -1.453233
# 8  -1.094135 -1.711466 -0.320637 -0.433721 -0.694137 -1.053877 -0.807545
# 9  -1.093723 -1.550025 -0.996723  0.054770 -0.182858 -0.959219 -0.753737
# 10 -1.093310 -1.428366 -0.978720 -0.050893  0.048460 -0.700917 -0.753737
# 11 -1.092898 -0.787549 -1.596100 -0.409477  0.553842 -0.999884 -0.807545
# ...

# %%
three[1].plot(label='anger',figsize=(16,8))



stock_pre[15].plot(label='close',figsize=(16,8))
plt.legend()
