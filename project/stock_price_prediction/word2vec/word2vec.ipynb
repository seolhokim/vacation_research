# %%
#https://datascienceschool.net/view-notebook/6927b0906f884a67b0da9310d3a581ee/


정제
#https://m.blog.naver.com/PostView.nhn?blogId=gee308&logNo=220870093426&targetKeyword=&targetRecommendationCode=1
# Out:
# C:\Users\ie-45\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Twitter 
import glob
import re
# Out:
# C:\Users\ie-45\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from gensim.models import word2vec

# %%
"""
model = Word2Vec('text',size = 'size', window='window', min_count = 'min')
model.init_sims(replace=True)
model.save('word2vec.model')
"""
# Out:
# "\nmodel = Word2Vec('text',size = 'size', window='window', min_count = 'min')\nmodel.init_sims(replace=True)\nmodel.save('word2vec.model')\n"

# %%
wiki_data = glob.glob("./data/*.txt")
tagger = Twitter()

# %%
def data_read(data_place):
    f = open(data_place,'r',encoding='utf-8')
    #print("opend")
    txt = f.read()
    #print("txt clear")
    hangle = re.compile('[^ ㄱ-ㅣ가-힣0-9]+')
    result = hangle.sub('',txt)
    #print("result clear")
    result = tagger.pos(result,norm=True,stem = True)
    return result

def train_data_make(data):
    r = []
    results = []
    jung_bok = ""
    for (word, pumsa) in data:
        if not pumsa in ["Josa", "Eomi", "Punctuation"] and jung_bok !=word:
            r.append(word)
            jung_bok = word
    results.append((" ".join(r)).strip())  
    return results
def train_data_to_txt(results,name = ''):
    with open(name,'w',encoding = 'utf-8') as fp:
        fp.write(results)

# %%
for i in range(100):
    result = data_read(wiki_data[i])
    result = train_data_make(result)
    dir_name = './data/wiki_data'+str(i)+'.txt'
    train_data_to_txt(result[0],dir_name)
    print(i,"/",100)

# %%
'''
#함수목록

#data_read(data_place) raw 데이터를 학습용데이터를만들어줌
#train_data_creation() file_name_list로 학습데이터 list만듬
#model_train model을 file_data_list로 학습시킴

def data_read(data_place):
    f = open(data_place,'r',encoding='utf-8')
    #print("opend")
    txt = f.read()
    #print("txt clear")
    hangle = re.compile('[^ ㄱ-ㅣ가-힣0-9]+')
    result = hangle.sub('',txt)
    #print("result clear")
    result = tagger.pos(result,norm=True,stem = True)
    return result

def train_data_creation(file_name_list):
    train_data= []
    for i in range(len(file_name_list)):
        train_data.append(data_read(file_name_list[i]))
    return train_data

def model_train(model,train_data_list):
    for i in range(len(train_data_list)):
        model.train(train_data_list[i],total_examples = model.corpus_count, epochs = model.epochs)
    return model
#model.save("word2vec.model")
#model.load("word2vec.model")

'''

# %%
#기본준비
'''
형태소 분리기  : tagger
movie_subtitle :파일 명 list
Word2Vec() 모델 w2v_model #파라미터 수정
'''
tagger = Twitter()
movie_subtitle = glob.glob(pathname='./movie_subtitle/*.txt') #list
#model = Word2Vec(data,size = 400, window = 5, min_count = 2,sg= 1) #로 생성함.skip
model = Word2Vec.load("word2vec.model")

# %%
model.init_sims(replace=True)
model.save('word2vec.model')

# %%
for i in range(1,100):
    data = data_read(wiki_data[i])
    model.train(data,total_examples = model.corpus_count, epochs = model.epochs)
    name = './model/w2v_model_20180720_'+str(i)+'.model'
    model.save(name)
    model.init_sims(replace=True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-26-3eae116a9649> in <module>()
#       1 for i in range(1,100):
# ----> 2     data = data_read(wiki_data[i])
#       3     model.train(data,total_examples = model.corpus_count, epochs = model.epochs)
#       4     name = './model/w2v_model_20180720_'+str(i)+'.model'
#       5     model.save(name)
#
# <ipython-input-5-d359c6391259> in data_read(data_place)
#       8     f = open(data_place,'r',encoding='utf-8')
#       9     #print("opend")
# ---> 10     txt = f.read()
#      11     #print("txt clear")
#      12     hangle = re.compile('[^ ㄱ-ㅣ가-힣0-9]+')
#
# ~\Anaconda3\lib\codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
# ...

# %%
model.most_similar("미국")
# Out:
# C:\Users\ie-45\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-60342015d666> in <module>()
# ----> 1 model.most_similar("미국")
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1417                     stacklevel=2
#    1418                 )
# -> 1419                 return func(*args, **kwargs)
#    1420
#    1421             return new_func1
#
# ~\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1239
#    1240         """
# ...

# %%
def find(name):
    return tagger.pos(name,norm=True,stem = True)

# %%
find("이다")
# Out:
# [('이다', 'Josa')]

# %%
a.epochs
# Out:
# 5

# %%
a.train(test2,total_examples=a.corpus_count, epochs=5)
# Out:
# (20294, 75310)

# %%
a.most_similar("사회")
# Out:
# C:\Users\ie-45\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-7c3ea2e034b7> in <module>()
# ----> 1 a.most_similar("사회")
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1417                     stacklevel=2
#    1418                 )
# -> 1419                 return func(*args, **kwargs)
#    1420
#    1421             return new_func1
#
# ~\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1239
#    1240         """
# ...

# %%
test
# Out:
# ['증권',
#  '분야',
#  '의',
#  '전문용어',
#  '가',
#  '많아',
#  '오역',
#  '이',
#  '있',
#  '을',
#  '수',
#  '있',
#  '습니다',
#  '욕설',
#  '이나',
#  '비속어',
#  '는',
#  '최대한',
#  '순화',
#  '시켰',
#  '습니다',
#  '저',
#  '사람',
#  '들',
#  '인가요',
#  '세상',
#  '에여',
#  '기',
#  '서',
#  '할',
#  '생각',
#  '인가요',
#  '자네',
#  '들',
#  '이런',
#  '거',
#  '경험',
#  '해',
#  '본',
#  '적',
#  '있',
#  '나',
#  '아',
#  '니요',
#  '자리',
#  '로',
#  '돌아가게',
#  '나',
#  '책상',
#  '에',
#  '머리',
#  '박고',
#  '신경',
#  '들',
#  '끄',
#  '고',
#  '있어',
#  '어서',
#  '신경',
#  '끄',
#  '게나',
#  '티모시',
#  '싱',
#  '씨',
#  '네',
#  '실례',
#  '지만',
#  '잠시',
#  '이야기',
#  '좀',
#  '할',
#  '까',
#  '요',
#  '가시',
#  '죠',
#  '에릭',
#  '데일',
#  '씨',
#  '네',
#  '아',
#  '아뇨네',
#  '제',
#  '가',
#  '아닌',
#  '데요',
#  '이런',
#  '죄송합',
#  '니다',
#  '제',
#  '상사',
#  '인데',
#  '아랫',
#  '층',
#  '에',
#  '계세',
#  '요',
#  '고마워',
#  '요',
#  '실례합',
#  '니다',
#  '데일',
#  '씨',
#  '잠시',
#  '보시',
#  '죠',
#  '그',
#  '러시',
#  '죠',
#  '저희',
#  '와',
#  '함께',
#  '자리',
#  '하시',
#  '게',
#  '되어',
# ...

# %%
a.train(test2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c6cc236d1f61> in <module>()
# ----> 1 a.train(test2)
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in train(self, sentences, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks)
#     854             sentences, total_examples=total_examples, total_words=total_words,
#     855             epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
# --> 856             queue_factor=queue_factor, report_delay=report_delay, compute_loss=compute_loss, callbacks=callbacks)
#     857
#     858     def score(self, sentences, total_sentences=int(1e6), chunksize=100, queue_factor=2, report_delay=1):
#
# ...
