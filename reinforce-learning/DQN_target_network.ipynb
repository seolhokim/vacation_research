# %%
#https://keon.io/deep-q-learning/
#에서 참고
# Out:
# C:\Users\sh2\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam
from collections import deque
import numpy as np
import gym
import random
from keras import backend as K
# Out:
# C:\Users\sh2\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen =2000)
        self.gamma = 0.95 # 보상이 느릴수록 페널티를 주기위해
        self.epsilon = 1.0 #e
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        self.learning_rate = 0.001
        self.target_model = self.build_model()
        self.main_model = self.build_model()
    
    def _huber_loss(self, target, prediction):
        # sqrt(1+error^2)-1
        error = prediction - target
        return K.mean(K.sqrt(1+K.square(error))-1, axis=-1)
    def build_model(self):
        model = Sequential()
        model.add(Dense(24,input_dim=self.state_size,activation='relu'))
        model.add(Dense(24, activation = 'relu'))
        model.add(Dense(self.action_size, activation = 'linear'))
        model.compile(loss=self._huber_loss , optimizer = Adam(lr=self.learning_rate))
        return model
    
    def remember(self, state, action, rewar, next_state, done):
        self.memory.append((state,action,reward,next_state,done))
    
    def act(self, state):
        if agent.epsilon > agent.epsilon_min:
            agent.epsilon *= agent.epsilon_decay  
        if np.random.rand() <= self.epsilon:     
            return random.randrange(self.action_size)
        act_values = self.main_model.predict(state)
        return np.argmax(act_values[0])
    
    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)

        #target_model
        #main_model
        for state, action, reward, next_state, done in minibatch:
            Q = self.main_model.predict(state)
            
            if done:
                Q[0][action] = reward
                
            else :
                t = self.target_model.predict(next_state)[0]
                Q[0][action] = reward + self.gamma * np.amax(t)
            
            self.main_model.fit(state,Q,epochs=1,verbose=0)

# %%
env = gym.make('CartPole-v1')

agent = DQNAgent(4,2)

# %%
score_board = []

# %%
episodes = 1000
batch_size= 32
done=False

for e in range(episodes):

    state = env.reset()
    state = np.reshape(state, [1, 4])
      
       
  
    for time_t in range(10001):
        env.render()
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        reward = reward if (not done) or time_t==499  else -100
        
        next_state = np.reshape(next_state, [1, 4])

        agent.remember(state, action, reward, next_state, done)        
        state = next_state
        if done:
            agent.target_model.set_weights(agent.main_model.get_weights())    
            print("episode: {}/{}, score: {}, e: {:.2}"
                    .format(e, episodes, time_t, agent.epsilon))
            break
    
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
    """
    if e % 10 == 1:
        for _ in range(50):
            agent.replay(batch_size)
    """
# Out:
# episode: 0/1000, score: 499, e: 0.01
# episode: 1/1000, score: 108, e: 0.01
# episode: 2/1000, score: 12, e: 0.01
# episode: 3/1000, score: 17, e: 0.01
# episode: 4/1000, score: 12, e: 0.01
# episode: 5/1000, score: 49, e: 0.01
# episode: 6/1000, score: 14, e: 0.01
# episode: 7/1000, score: 66, e: 0.01
# episode: 8/1000, score: 19, e: 0.01
# episode: 9/1000, score: 10, e: 0.01
# episode: 10/1000, score: 12, e: 0.01
# episode: 11/1000, score: 51, e: 0.01
# episode: 12/1000, score: 151, e: 0.01
# episode: 13/1000, score: 132, e: 0.01
# episode: 80/1000, score: 18, e: 0.01
# episode: 81/1000, score: 58, e: 0.01
# episode: 82/1000, score: 134, e: 0.01
# episode: 83/1000, score: 16, e: 0.01
# episode: 84/1000, score: 15, e: 0.01
# episode: 85/1000, score: 28, e: 0.01
# episode: 86/1000, score: 17, e: 0.01
# episode: 87/1000, score: 10, e: 0.01
# episode: 88/1000, score: 53, e: 0.01
# episode: 89/1000, score: 11, e: 0.01
# episode: 90/1000, score: 17, e: 0.01
# episode: 91/1000, score: 208, e: 0.01
# episode: 92/1000, score: 22, e: 0.01
# episode: 93/1000, score: 17, e: 0.01
# episode: 94/1000, score: 21, e: 0.01
# episode: 95/1000, score: 215, e: 0.01
# episode: 96/1000, score: 56, e: 0.01
# episode: 97/1000, score: 72, e: 0.01
# episode: 98/1000, score: 168, e: 0.01
# episode: 99/1000, score: 136, e: 0.01
# episode: 100/1000, score: 157, e: 0.01
# episode: 101/1000, score: 244, e: 0.01
# episode: 102/1000, score: 499, e: 0.01
# episode: 103/1000, score: 188, e: 0.01
# episode: 104/1000, score: 158, e: 0.01
# episode: 105/1000, score: 32, e: 0.01
# episode: 106/1000, score: 45, e: 0.01
# episode: 107/1000, score: 262, e: 0.01
# episode: 108/1000, score: 499, e: 0.01
# episode: 109/1000, score: 94, e: 0.01
# episode: 110/1000, score: 34, e: 0.01
# episode: 111/1000, score: 20, e: 0.01
# episode: 112/1000, score: 21, e: 0.01
# episode: 113/1000, score: 143, e: 0.01
# episode: 114/1000, score: 83, e: 0.01
# episode: 115/1000, score: 88, e: 0.01
# episode: 116/1000, score: 49, e: 0.01
# episode: 117/1000, score: 50, e: 0.01
# episode: 118/1000, score: 29, e: 0.01
# episode: 119/1000, score: 74, e: 0.01
# episode: 120/1000, score: 66, e: 0.01
# episode: 121/1000, score: 193, e: 0.01

# %%
env = gym.make('CartPole-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
agent = DQNAgent(state_size, action_size)
# agent.load("./save/cartpole-ddqn.h5")
score_board = []

# %%
done = False
batch_size = 32
EPISODES = 100
for e in range(EPISODES):
    #state = env.reset()
    state = np.reshape(state, [1, state_size])
    for time in range(10001): #학습이 잘되면 늘려줘도됨.
        env.render()
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        reward = reward if not done else -10
        next_state = np.reshape(next_state, [1, state_size])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        if done:
            agent.update_target_model()
            score_board.append(time)
            print("episode: {}/{}, score: {}, e: {:.2}"
                    .format(e, EPISODES, time, agent.epsilon))
            break
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-c73601828515> in <module>()
#      14         state = next_state
#      15         if done:
# ---> 16             agent.update_target_model()
#      17             score_board.append(time)
#      18             print("episode: {}/{}, score: {}, e: {:.2}"
#
# AttributeError: 'DQNAgent' object has no attribute 'update_target_model'
