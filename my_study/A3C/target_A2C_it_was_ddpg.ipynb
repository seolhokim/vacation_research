# %%
#덱도 추가해서 dqn처럼만들것

# %%
from collections import deque
import sys
import gym
import pylab
import numpy as np
from keras.layers import Dense,merge
from keras.models import Sequential ,Input, Model
from keras.optimizers import Adam
from keras import backend as K
import random
import matplotlib.pyplot as plt

# %%
from numpy.random import randint

# %%
#target만들어서 해줘보자
class ActorCriticModel:
    def __init__(self,state_size,action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.value_size = 1
        
        self.discount_factor = 0.99
        self.actor_lr = 0.001
        self.critic_lr = 0.005
        self.epsilon = 1
        self.decaying_epsilon = 0.999
        self.tau = 0.001
        self.memory = deque(maxlen =2000)
        
        self.actor ,_ = self.build_actor()
        self.target_actor,_ = self.build_actor()
        #
        self.actor_updater = self.actor_optimizer()
        self.target_actor_updater = self.actor_optimizer()
        
        self.critic = self.build_critic()
        self.target_critic = self.build_critic()
        self.critic_updater = self.critic_optimizer()
        self.target_critic_updater = self.critic_optimizer()
        
        
        
    def build_actor(self):
        input_layer = Input(shape =(self.state_size,))
        h1 = Dense(24, activation ='relu',kernel_initializer='he_uniform')(input_layer)
        h2 = Dense(24, activation ='relu',kernel_initializer='he_uniform')(h1)
        h3 = Dense(self.action_size, activation = 'relu',kernel_initializer='he_uniform')(h2)
        output = Dense(self.action_size, activation='softmax',kernel_initializer='he_uniform')(h3)
        model = Model(inputs =input_layer, outputs = output)
        return model,input_layer
        
    def build_critic(self):
        critic = Sequential()
        critic.add(Dense(24, input_dim=self.state_size, activation='relu',
                         kernel_initializer='he_uniform'))
        critic.add(Dense(24, input_dim=self.state_size, activation='relu',
                         kernel_initializer='he_uniform'))
        critic.add(Dense(self.value_size, activation='linear',
                         kernel_initializer='he_uniform'))
        return critic
        
        
        #return model
        
    def get_action(self,state):
        if(random.random()< self.epsilon):
            if(self.epsilon > 0.01):
                self.epsilon = self.epsilon * self.decaying_epsilon
            
            return randint((self.action_size))
        
        policy= self.target_actor.predict(state) #.flatten()
        #print(policy)
        #print(np.random.choice(self.action_size,1,p=policy[0])[0])
        return np.random.choice(self.action_size,1,p=policy[0])[0]
        
    def actor_optimizer(self):
        action = K.placeholder(shape =[None, self.action_size])
        advantage = K.placeholder(shape=[None,])
        action_prob = K.sum(action * self.actor.output,axis = 1)
        cross_entropy = K.log(action_prob) * advantage
        loss = -K.sum(cross_entropy) #최대화하려면 마이너스?
        
        optimizer = Adam(lr=self.actor_lr)
        updates = optimizer.get_updates(self.actor.trainable_weights,[],loss)
        train = K.function([self.actor.input,action,advantage],[],updates=updates)
        return train
            
    def critic_optimizer(self):
        target = K.placeholder(shape=[None,])
        loss = K.mean(K.square(target - self.critic.output))
        
        optimizer = Adam(lr=self.critic_lr)
        updates = optimizer.get_updates(self.critic.trainable_weights,[],loss)
        train = K.function([self.critic.input,target],[],updates = updates)
        return train
    
    def target_actor_train(self):
        actor_weights = self.actor.get_weights()
        actor_target_weights = self.target_actor.get_weights()
        for i in range(len(actor_weights)):
            actor_target_weights[i] = self.tau * actor_weights[i] + (1-self.tau) \
            * actor_target_weights[i]
        self.target_actor.set_weights(actor_target_weights)
    
    def target_critic_train(self):
        critic_weights = self.critic.get_weights()
        critic_target_weights = self.target_critic.get_weights()
        for i in range(len(critic_weights)):
            critic_target_weights[i] = self.tau * critic_weights[i] + (1-self.tau)\
            * critic_target_weights[i]
        self.target_critic.set_weights(critic_target_weights)
    
    def train_model(self,batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        for state, action, reward, next_state, done in minibatch:
            value = self.target_critic.predict(state)[0]
            next_value = self.target_critic.predict(next_state)[0]
            
            #print(value)
            act = np.zeros([1,self.action_size])
            act[0][action] = 1


            if done:
                advantage = reward - value
                target = [reward]

            else :
                advantage = (reward + self.discount_factor * next_value) - value
                target = reward + self.discount_factor * next_value
            self.actor_updater([state,act,advantage])
            self.critic_updater([state,target])
        self.target_actor_train()
        self.target_critic_train()
        self.memory.clear()
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state,action,reward,next_state,done))

# %%
    # CartPole-v1 환경, 최대 타임스텝 수가 500
EPISODES = 100
env = gym.make('CartPole-v1')
    # 환경으로부터 상태와 행동의 크기를 받아옴
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

    # 액터-크리틱(A2C) 에이전트 생성
agent = ActorCriticModel(state_size, action_size)

scores, episodes = [], []

# %%
batch_size = 128
for e in range(1000):
    done = False
    score = 0
    rendering = False
    state = env.reset()
    state = np.reshape(state, [1, state_size])

    while not done:
        if rendering:
            env.render()

        action = agent.get_action(state)
        #print(action)
        next_state, reward, done, info = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
            # 에피소드가 중간에 끝나면 -100 보상
        reward = reward if not done or score == 499 else -100
        agent.remember(state, action, reward, next_state, done)  
        #agent.train_model(state, action, reward, next_state, done)

        score += reward
        state = next_state
        if done:
                # 에피소드마다 학습 결과 출력
            score = score if score == 500.0 else score + 100
            scores.append(score)
            episodes.append(e)
            print("episode:", e, "  score:", score)

                # 이전 10개 에피소드의 점수 평균이 490보다 크면 학습 중단
            if np.mean(scores[-min(10, len(scores)):]) > 490:
                    #agent.actor.save_weights("./save_model/cartpole_actor.h5")
                    #agent.critic.save_weights(
                    #    "./save_model/cartpole_critic.h5")
                sys.exit()
        if len(agent.memory) > batch_size:
            agent.train_model(batch_size)
# Out:
# episode: 0   score: 21.0
# episode: 1   score: 19.0
# episode: 2   score: 13.0
# episode: 3   score: 19.0
# episode: 4   score: 13.0
# episode: 5   score: 17.0
# episode: 6   score: 13.0
# episode: 7   score: 17.0
# episode: 8   score: 12.0
# episode: 9   score: 12.0
# episode: 10   score: 12.0
# episode: 11   score: 17.0
# episode: 12   score: 18.0
# episode: 13   score: 20.0
# episode: 14   score: 22.0
# episode: 15   score: 16.0
# episode: 16   score: 27.0
# episode: 17   score: 43.0
# episode: 18   score: 22.0
# episode: 19   score: 18.0
# episode: 20   score: 39.0
# episode: 21   score: 24.0
# episode: 22   score: 15.0
# episode: 23   score: 19.0
# episode: 24   score: 11.0
# episode: 25   score: 28.0
# episode: 26   score: 31.0
# episode: 27   score: 12.0
# episode: 28   score: 12.0
# episode: 29   score: 46.0
# episode: 30   score: 15.0
# episode: 31   score: 30.0
# episode: 32   score: 26.0
# episode: 33   score: 38.0
# episode: 34   score: 13.0
# episode: 35   score: 26.0
# episode: 36   score: 16.0
# episode: 37   score: 11.0
# episode: 38   score: 15.0
# episode: 39   score: 20.0
# episode: 40   score: 34.0
# episode: 41   score: 13.0
# episode: 42   score: 24.0
# episode: 43   score: 13.0
# episode: 44   score: 17.0
# episode: 45   score: 14.0
# episode: 46   score: 14.0
# episode: 47   score: 33.0
# episode: 48   score: 40.0
# episode: 49   score: 15.0
# episode: 50   score: 40.0
# episode: 51   score: 11.0
# episode: 52   score: 15.0
# episode: 53   score: 11.0
# episode: 54   score: 21.0
# episode: 55   score: 10.0
# episode: 56   score: 15.0
# episode: 57   score: 17.0
# episode: 58   score: 18.0
# episode: 59   score: 29.0
# episode: 60   score: 11.0
# episode: 61   score: 17.0
# episode: 62   score: 12.0
# episode: 63   score: 25.0
# episode: 64   score: 8.0
# episode: 65   score: 24.0
# episode: 66   score: 10.0
# episode: 67   score: 28.0
# episode: 68   score: 12.0
# episode: 69   score: 27.0
# episode: 70   score: 21.0
# episode: 71   score: 15.0
# episode: 72   score: 24.0
# episode: 73   score: 15.0
# episode: 74   score: 15.0
# episode: 75   score: 22.0
# episode: 76   score: 21.0
# episode: 77   score: 18.0
# episode: 78   score: 47.0
# episode: 79   score: 15.0
# episode: 80   score: 24.0
# episode: 81   score: 21.0
# episode: 82   score: 25.0
# episode: 83   score: 16.0
# episode: 84   score: 32.0
# episode: 85   score: 16.0
# episode: 86   score: 18.0
# episode: 87   score: 28.0
# episode: 88   score: 11.0
# episode: 89   score: 17.0
# episode: 90   score: 10.0
# episode: 91   score: 19.0
# episode: 92   score: 13.0
# episode: 93   score: 46.0
# episode: 94   score: 18.0
# episode: 95   score: 27.0
# episode: 96   score: 24.0
# episode: 97   score: 16.0
# episode: 98   score: 23.0
# episode: 99   score: 16.0
# episode: 100   score: 21.0
# episode: 101   score: 11.0
# episode: 102   score: 46.0
# episode: 103   score: 33.0
# episode: 104   score: 22.0
# episode: 105   score: 34.0
# episode: 106   score: 58.0
# episode: 107   score: 27.0
# episode: 108   score: 33.0
# episode: 109   score: 11.0
# episode: 110   score: 23.0
# episode: 111   score: 27.0
# episode: 112   score: 13.0
# episode: 113   score: 14.0
# episode: 114   score: 37.0
# episode: 115   score: 16.0
# episode: 116   score: 29.0
# episode: 117   score: 10.0
# episode: 118   score: 9.0
# episode: 119   score: 10.0
# episode: 120   score: 52.0
# episode: 121   score: 36.0
# episode: 122   score: 16.0
# episode: 123   score: 17.0
# episode: 124   score: 18.0
# episode: 125   score: 16.0
# episode: 126   score: 13.0
# episode: 127   score: 39.0
# episode: 128   score: 15.0
# episode: 129   score: 16.0
# episode: 130   score: 8.0
# episode: 131   score: 49.0
# episode: 132   score: 17.0
# episode: 133   score: 12.0
# episode: 134   score: 12.0
# episode: 135   score: 19.0
# episode: 136   score: 53.0
# episode: 137   score: 27.0
# episode: 138   score: 12.0
# episode: 139   score: 24.0
# episode: 140   score: 11.0
# episode: 141   score: 38.0
# episode: 142   score: 13.0
# episode: 143   score: 12.0
# episode: 144   score: 35.0
# episode: 145   score: 15.0
# episode: 146   score: 23.0
# episode: 147   score: 12.0
# episode: 148   score: 22.0
# episode: 149   score: 34.0
# episode: 150   score: 19.0
# episode: 151   score: 13.0
# episode: 152   score: 14.0
# episode: 153   score: 41.0
# episode: 154   score: 44.0
# episode: 155   score: 11.0
# episode: 156   score: 16.0
# episode: 157   score: 17.0
# episode: 158   score: 38.0
# episode: 159   score: 7.0
# episode: 160   score: 20.0
# episode: 161   score: 16.0
# episode: 162   score: 49.0
# episode: 163   score: 13.0
# episode: 164   score: 26.0
# episode: 165   score: 11.0
# episode: 166   score: 20.0
# episode: 167   score: 69.0
# episode: 168   score: 11.0
# episode: 169   score: 20.0
# episode: 170   score: 20.0
# episode: 171   score: 39.0
# episode: 172   score: 16.0
# episode: 173   score: 27.0
# episode: 174   score: 19.0
# episode: 175   score: 9.0
# episode: 176   score: 21.0
# episode: 177   score: 12.0
# episode: 178   score: 28.0
# episode: 179   score: 29.0
# episode: 180   score: 27.0
# episode: 181   score: 64.0
# episode: 182   score: 44.0
# episode: 183   score: 32.0
# episode: 184   score: 31.0
# episode: 185   score: 13.0
# episode: 186   score: 25.0
# episode: 187   score: 20.0
# episode: 188   score: 11.0
# episode: 189   score: 28.0
# episode: 190   score: 48.0
# episode: 191   score: 38.0
# episode: 192   score: 9.0
# episode: 193   score: 10.0
# episode: 194   score: 36.0
# episode: 195   score: 11.0
# episode: 196   score: 26.0
# episode: 197   score: 11.0
# episode: 198   score: 9.0
# episode: 199   score: 16.0
# episode: 200   score: 37.0
# episode: 201   score: 13.0
# episode: 202   score: 26.0
# episode: 203   score: 14.0
# episode: 204   score: 60.0
# episode: 205   score: 16.0
# episode: 206   score: 24.0
# episode: 207   score: 9.0
# episode: 208   score: 17.0
# episode: 209   score: 26.0
# episode: 210   score: 11.0
# episode: 211   score: 9.0
# episode: 212   score: 9.0
# episode: 213   score: 15.0
# episode: 214   score: 15.0
# episode: 215   score: 34.0
# episode: 216   score: 12.0
# episode: 217   score: 46.0
# episode: 218   score: 26.0
# episode: 219   score: 48.0
# episode: 220   score: 14.0
# episode: 221   score: 12.0
# episode: 222   score: 12.0
# episode: 223   score: 15.0
# episode: 224   score: 22.0
# episode: 225   score: 14.0
# episode: 226   score: 27.0
# episode: 227   score: 14.0
# episode: 228   score: 26.0
# episode: 229   score: 16.0
# episode: 230   score: 14.0
# episode: 231   score: 9.0
# episode: 232   score: 21.0
# episode: 233   score: 17.0
# episode: 234   score: 54.0
# episode: 235   score: 48.0
# episode: 236   score: 24.0
# episode: 237   score: 27.0
# episode: 238   score: 14.0
# episode: 239   score: 12.0
# episode: 240   score: 24.0
# episode: 241   score: 17.0
# episode: 242   score: 31.0
# episode: 243   score: 13.0
# episode: 244   score: 27.0
# episode: 245   score: 22.0
# episode: 246   score: 13.0
# episode: 247   score: 12.0
# episode: 248   score: 11.0
# episode: 249   score: 16.0
# episode: 250   score: 19.0
# episode: 251   score: 15.0
# episode: 252   score: 17.0
# episode: 253   score: 40.0
# episode: 254   score: 32.0
# episode: 255   score: 11.0
# episode: 256   score: 15.0
# episode: 257   score: 10.0
# episode: 258   score: 23.0
# episode: 259   score: 42.0
# episode: 260   score: 11.0
# episode: 261   score: 20.0
# episode: 262   score: 21.0
# episode: 263   score: 37.0
# episode: 264   score: 30.0
# episode: 265   score: 19.0
# episode: 266   score: 32.0
# episode: 267   score: 34.0
# episode: 268   score: 10.0
# episode: 269   score: 14.0
# episode: 270   score: 8.0
# episode: 271   score: 17.0
# episode: 272   score: 12.0
# episode: 273   score: 9.0
# episode: 274   score: 33.0
# episode: 275   score: 16.0
# episode: 276   score: 32.0
# episode: 277   score: 49.0
# episode: 278   score: 15.0
# episode: 279   score: 19.0
# episode: 280   score: 21.0
# episode: 281   score: 62.0
# episode: 282   score: 23.0
# episode: 283   score: 8.0
# episode: 284   score: 43.0
# episode: 285   score: 12.0
# episode: 286   score: 22.0
# episode: 287   score: 10.0
# episode: 288   score: 30.0
# episode: 289   score: 16.0
# episode: 290   score: 24.0
# episode: 291   score: 38.0
# episode: 292   score: 9.0
# episode: 293   score: 37.0
# episode: 294   score: 20.0
# episode: 295   score: 21.0
# episode: 296   score: 26.0
# episode: 297   score: 38.0
# episode: 298   score: 14.0
# episode: 299   score: 36.0
# episode: 300   score: 15.0
# episode: 301   score: 27.0
# episode: 302   score: 33.0
# episode: 303   score: 41.0
# episode: 304   score: 10.0
# episode: 305   score: 13.0
# episode: 306   score: 20.0
# episode: 307   score: 30.0
# episode: 308   score: 49.0
# episode: 309   score: 21.0
# episode: 310   score: 22.0
# episode: 311   score: 27.0
# episode: 312   score: 14.0
# episode: 313   score: 17.0
# episode: 314   score: 54.0
# episode: 315   score: 11.0
# episode: 316   score: 12.0
# episode: 317   score: 23.0
# episode: 318   score: 10.0
# episode: 319   score: 23.0
# episode: 320   score: 14.0
# episode: 321   score: 21.0
# episode: 322   score: 13.0
# episode: 323   score: 11.0
# episode: 324   score: 14.0
# episode: 325   score: 21.0
# episode: 326   score: 10.0
# episode: 327   score: 24.0
# episode: 328   score: 31.0
# episode: 329   score: 13.0
# episode: 330   score: 15.0
# episode: 331   score: 10.0
# episode: 332   score: 22.0
# episode: 333   score: 26.0
# episode: 334   score: 51.0
# episode: 335   score: 31.0
# episode: 336   score: 26.0
# episode: 337   score: 13.0
# episode: 338   score: 10.0
# episode: 339   score: 17.0
# episode: 340   score: 17.0
# episode: 341   score: 20.0
# episode: 342   score: 24.0
# episode: 343   score: 21.0
# episode: 344   score: 11.0
# episode: 345   score: 33.0
# episode: 346   score: 13.0
# episode: 347   score: 24.0
# episode: 348   score: 20.0
# episode: 349   score: 11.0
# episode: 350   score: 13.0
# episode: 351   score: 20.0
# episode: 352   score: 29.0
# episode: 353   score: 36.0
# episode: 354   score: 10.0
# episode: 355   score: 15.0
# episode: 356   score: 11.0
# episode: 357   score: 13.0
# episode: 358   score: 13.0
# episode: 359   score: 23.0
# episode: 360   score: 10.0
# episode: 361   score: 14.0
# episode: 362   score: 21.0
# episode: 363   score: 22.0
# episode: 364   score: 15.0
# episode: 365   score: 54.0
# episode: 366   score: 11.0
# episode: 367   score: 11.0
# episode: 368   score: 9.0
# episode: 369   score: 11.0
# episode: 370   score: 29.0
# episode: 371   score: 11.0
# episode: 372   score: 41.0
# episode: 373   score: 17.0
# episode: 374   score: 22.0
# episode: 375   score: 34.0
# episode: 376   score: 40.0
# episode: 377   score: 20.0
# episode: 378   score: 16.0
# episode: 379   score: 10.0
# episode: 380   score: 24.0
# episode: 381   score: 21.0
# episode: 382   score: 20.0
# episode: 383   score: 14.0
# episode: 384   score: 11.0
# episode: 385   score: 25.0
# episode: 386   score: 17.0
# episode: 387   score: 18.0
# episode: 388   score: 11.0
# episode: 389   score: 51.0
# episode: 390   score: 12.0
# episode: 391   score: 18.0
# episode: 392   score: 18.0
# episode: 393   score: 40.0
# episode: 394   score: 28.0
# episode: 395   score: 47.0
# episode: 396   score: 11.0
# episode: 397   score: 8.0
# episode: 398   score: 31.0
# episode: 399   score: 27.0
# episode: 400   score: 10.0
# episode: 401   score: 27.0
# episode: 402   score: 12.0
# episode: 403   score: 10.0
# episode: 404   score: 14.0
# episode: 405   score: 19.0
# episode: 406   score: 26.0
# episode: 407   score: 16.0
# episode: 408   score: 22.0
# episode: 409   score: 15.0
# episode: 410   score: 10.0
# episode: 411   score: 19.0
# episode: 412   score: 22.0
# episode: 413   score: 12.0
# episode: 414   score: 17.0
# episode: 415   score: 12.0
# episode: 416   score: 14.0
# episode: 417   score: 15.0
# episode: 418   score: 28.0
# episode: 419   score: 19.0
# episode: 420   score: 49.0
# episode: 421   score: 18.0
# episode: 422   score: 18.0
# episode: 423   score: 10.0
# episode: 424   score: 27.0
# episode: 425   score: 31.0
# episode: 426   score: 18.0
# episode: 427   score: 48.0
# episode: 428   score: 31.0
# episode: 429   score: 27.0
# episode: 430   score: 20.0
# episode: 431   score: 10.0
# episode: 432   score: 9.0
# episode: 433   score: 18.0
# episode: 434   score: 25.0
# episode: 435   score: 17.0
# episode: 436   score: 12.0
# episode: 437   score: 18.0
# episode: 438   score: 17.0
# episode: 439   score: 17.0
# episode: 440   score: 19.0
# episode: 441   score: 38.0
# episode: 442   score: 23.0
# episode: 443   score: 13.0
# episode: 444   score: 58.0
# episode: 445   score: 18.0
# episode: 446   score: 14.0
# episode: 447   score: 17.0
# episode: 448   score: 20.0
# episode: 449   score: 12.0
# episode: 450   score: 9.0
# episode: 451   score: 9.0
# episode: 452   score: 14.0
# episode: 453   score: 13.0
# episode: 454   score: 20.0
# episode: 455   score: 34.0
# episode: 456   score: 10.0
# episode: 457   score: 11.0
# episode: 458   score: 15.0
# episode: 459   score: 19.0
# episode: 460   score: 18.0
# episode: 461   score: 13.0
# episode: 462   score: 20.0
# episode: 463   score: 23.0
# episode: 464   score: 9.0
# episode: 465   score: 10.0
# episode: 466   score: 16.0
# episode: 467   score: 10.0
# episode: 468   score: 13.0
# episode: 469   score: 10.0
# episode: 470   score: 16.0
# episode: 471   score: 15.0
# episode: 472   score: 10.0
# episode: 473   score: 15.0
# episode: 474   score: 57.0
# episode: 475   score: 16.0
# episode: 476   score: 19.0
# episode: 477   score: 23.0
# episode: 478   score: 10.0
# episode: 479   score: 10.0
# episode: 480   score: 64.0
# episode: 481   score: 35.0
# episode: 482   score: 29.0
# episode: 483   score: 11.0
# episode: 484   score: 15.0
# episode: 485   score: 9.0
# episode: 486   score: 19.0
# episode: 487   score: 10.0
# episode: 488   score: 28.0
# episode: 489   score: 38.0
# episode: 490   score: 15.0
# episode: 491   score: 16.0
# episode: 492   score: 21.0
# episode: 493   score: 11.0
# episode: 494   score: 26.0
# episode: 495   score: 10.0
# episode: 496   score: 33.0
# episode: 497   score: 28.0
# episode: 498   score: 27.0
# episode: 499   score: 30.0
# episode: 500   score: 17.0
# episode: 501   score: 41.0
# episode: 502   score: 15.0
# episode: 503   score: 9.0
# episode: 504   score: 24.0
# episode: 505   score: 31.0
# episode: 506   score: 15.0
# episode: 507   score: 30.0
# episode: 508   score: 17.0
# episode: 509   score: 23.0
# episode: 510   score: 20.0
# episode: 511   score: 11.0
# episode: 512   score: 28.0
# episode: 513   score: 58.0
# episode: 514   score: 14.0
# episode: 515   score: 18.0
# episode: 516   score: 16.0
# episode: 517   score: 27.0
# episode: 518   score: 18.0
# episode: 519   score: 44.0
# episode: 520   score: 16.0
# episode: 521   score: 11.0
# episode: 522   score: 19.0
# episode: 523   score: 11.0
# episode: 524   score: 31.0
# episode: 525   score: 24.0
# episode: 526   score: 14.0
# episode: 527   score: 18.0
# episode: 528   score: 28.0
# episode: 529   score: 38.0
# episode: 530   score: 20.0
# episode: 531   score: 18.0
# episode: 532   score: 45.0
# episode: 533   score: 34.0
# episode: 534   score: 22.0
# episode: 535   score: 31.0
# episode: 536   score: 29.0
# episode: 537   score: 27.0
# episode: 538   score: 11.0
# episode: 539   score: 13.0
# episode: 540   score: 20.0
# episode: 541   score: 14.0
# episode: 542   score: 11.0
# episode: 543   score: 20.0
# episode: 544   score: 37.0
# episode: 545   score: 10.0
# episode: 546   score: 19.0
# episode: 547   score: 18.0
# episode: 548   score: 42.0
# episode: 549   score: 10.0
# episode: 550   score: 16.0
# episode: 551   score: 23.0
# episode: 552   score: 9.0
# episode: 553   score: 31.0
# episode: 554   score: 16.0
# episode: 555   score: 31.0
# episode: 556   score: 13.0
# episode: 557   score: 16.0
# episode: 558   score: 33.0
# episode: 559   score: 24.0
# episode: 560   score: 21.0
# episode: 561   score: 14.0
# episode: 562   score: 10.0
# episode: 563   score: 22.0
# episode: 564   score: 28.0
# episode: 565   score: 14.0
# episode: 566   score: 15.0
# episode: 567   score: 17.0
# episode: 568   score: 19.0
# episode: 569   score: 10.0
# episode: 570   score: 10.0
# episode: 571   score: 17.0
# episode: 572   score: 17.0
# episode: 573   score: 17.0
# episode: 574   score: 19.0
# episode: 575   score: 19.0
# episode: 576   score: 19.0
# episode: 577   score: 33.0
# episode: 578   score: 14.0
# episode: 579   score: 12.0
# episode: 580   score: 21.0
# episode: 581   score: 56.0
# episode: 582   score: 11.0
# episode: 583   score: 25.0
# episode: 584   score: 10.0
# episode: 585   score: 18.0
# episode: 586   score: 11.0
# episode: 587   score: 31.0
# episode: 588   score: 9.0
# episode: 589   score: 16.0
# episode: 590   score: 15.0
# episode: 591   score: 15.0
# episode: 592   score: 31.0
# episode: 593   score: 47.0
# episode: 594   score: 9.0
# episode: 595   score: 44.0
# episode: 596   score: 18.0
# episode: 597   score: 47.0
# episode: 598   score: 28.0
# episode: 599   score: 8.0
# episode: 600   score: 9.0
# episode: 601   score: 12.0
# episode: 602   score: 10.0
# episode: 603   score: 18.0
# episode: 604   score: 30.0
# episode: 605   score: 18.0
# episode: 606   score: 16.0
# episode: 607   score: 13.0
# episode: 608   score: 11.0
# episode: 609   score: 32.0
# episode: 610   score: 20.0
# episode: 611   score: 16.0
# episode: 612   score: 12.0
# episode: 613   score: 14.0
# episode: 614   score: 15.0
# episode: 615   score: 13.0
# episode: 616   score: 16.0
# episode: 617   score: 13.0
# episode: 618   score: 22.0
# episode: 619   score: 37.0
# episode: 620   score: 53.0
# episode: 621   score: 17.0
# episode: 622   score: 12.0
# episode: 623   score: 56.0
# episode: 624   score: 31.0
# episode: 625   score: 26.0
# episode: 626   score: 27.0
# episode: 627   score: 13.0
# episode: 628   score: 22.0
# episode: 629   score: 34.0
# episode: 630   score: 12.0
# episode: 631   score: 13.0
# episode: 632   score: 16.0
# episode: 633   score: 22.0
# episode: 634   score: 46.0
# episode: 635   score: 23.0
# episode: 636   score: 15.0
# episode: 637   score: 13.0
# episode: 638   score: 18.0
# episode: 639   score: 9.0
# episode: 640   score: 10.0
# episode: 641   score: 20.0
# episode: 642   score: 21.0
# episode: 643   score: 20.0
# episode: 644   score: 8.0
# episode: 645   score: 11.0
# episode: 646   score: 20.0
# episode: 647   score: 15.0
# episode: 648   score: 13.0
# episode: 649   score: 14.0
# episode: 650   score: 14.0
# episode: 651   score: 25.0
# episode: 652   score: 8.0
# episode: 653   score: 14.0
# episode: 654   score: 15.0
# episode: 655   score: 12.0
# episode: 656   score: 28.0
# episode: 657   score: 9.0
# episode: 658   score: 18.0
# episode: 659   score: 23.0
# episode: 660   score: 27.0
# episode: 661   score: 11.0
# episode: 662   score: 11.0
# episode: 663   score: 13.0
# episode: 664   score: 24.0
# episode: 665   score: 11.0
# episode: 666   score: 36.0
# episode: 667   score: 22.0
# episode: 668   score: 17.0
# episode: 669   score: 55.0
# episode: 670   score: 17.0
# episode: 671   score: 8.0
# episode: 672   score: 9.0
# episode: 673   score: 24.0
# episode: 674   score: 32.0
# episode: 675   score: 17.0
# episode: 676   score: 39.0
# episode: 677   score: 28.0
# episode: 678   score: 15.0
# episode: 679   score: 15.0
# episode: 680   score: 16.0
# episode: 681   score: 36.0
# episode: 682   score: 20.0
# episode: 683   score: 14.0
# episode: 684   score: 38.0
# episode: 685   score: 26.0
# episode: 686   score: 15.0
# episode: 687   score: 13.0
# episode: 688   score: 11.0
# episode: 689   score: 18.0
# episode: 690   score: 19.0
# episode: 691   score: 19.0
# episode: 692   score: 10.0
# episode: 693   score: 22.0
# episode: 694   score: 13.0
# episode: 695   score: 15.0
# episode: 696   score: 13.0
# episode: 697   score: 8.0
# episode: 698   score: 15.0
# episode: 699   score: 12.0
# episode: 700   score: 18.0
# episode: 701   score: 28.0
# episode: 702   score: 17.0
# episode: 703   score: 29.0
# episode: 704   score: 25.0
# episode: 705   score: 36.0
# episode: 706   score: 9.0
# episode: 707   score: 15.0
# episode: 708   score: 18.0
# episode: 709   score: 19.0
# episode: 710   score: 13.0
# episode: 711   score: 20.0
# episode: 712   score: 11.0
# episode: 713   score: 18.0
# episode: 714   score: 24.0
# episode: 715   score: 14.0
# episode: 716   score: 12.0
# episode: 717   score: 23.0
# episode: 718   score: 36.0
# episode: 719   score: 31.0
# episode: 720   score: 38.0
# episode: 721   score: 56.0
# episode: 722   score: 19.0
# episode: 723   score: 12.0
# episode: 724   score: 17.0
# episode: 725   score: 24.0
# episode: 726   score: 20.0
# episode: 727   score: 13.0
# episode: 728   score: 10.0
# episode: 729   score: 43.0
# episode: 730   score: 12.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-10da1046c417> in <module>()
#      36                 sys.exit()
#      37         if len(agent.memory) > batch_size:
# ---> 38             agent.train_model(batch_size)
#
# <ipython-input-205-038a05dc910d> in train_model(self, batch_size)
#     100
#     101         for state, action, reward, next_state, done in minibatch:
# --> 102             value = self.target_critic.predict(state)[0]
#     103             next_value = self.target_critic.predict(next_state)[0]
#     104
#
# ~\Anaconda3\lib\site-packages\keras\models.py in predict(self, x, batch_size, verbose, steps)
#    1023             self.build()
#    1024         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1025                                   steps=steps)
#    1026
#    1027     def predict_on_batch(self, x):
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1840         f = self.predict_function
#    1841         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1842                                   verbose=verbose, steps=steps)
#    1843
#    1844     def train_on_batch(self, x, y,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1335                     ins_batch[i] = ins_batch[i].toarray()
#    1336
# -> 1337                 batch_outs = f(ins_batch)
#    1338                 if not isinstance(batch_outs, list):
#    1339                     batch_outs = [batch_outs]
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2471             feed_dict[tensor] = value
#    2472         fetches = self.outputs + [self.updates_op] + self.fetches
# -> 2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
#    2475                               **self.session_kwargs)
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     181             candidate_vars = []
#     182             for v in variables:
# --> 183                 if not getattr(v, '_keras_initialized', False):
#     184                     candidate_vars.append(v)
#     185             if candidate_vars:
#
# KeyboardInterrupt:

# %%
plt.plot(scores)
plt.show()

# %%
test = deque(maxlen = 3)

# %%
test.append("a")

# %%
# Out:
# 1
